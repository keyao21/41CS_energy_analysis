# %%
import pandas as pd
import datetime as datetime
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')
import os
import calendar

# %% [markdown]
# # Weather Data

# %%
# Get daily 2016 weather data

weather = pd.read_csv('weather_data/weather_data_nyc_centralpark_2016.csv')
weather['date'] = pd.to_datetime(weather['date'], format='%d-%m-%Y')
weather = weather.set_index('date')

# %%
weather.head()
# Out:
#             maximum temperature  minimum temperature  average temperature  \
# date
# 2016-01-01                   42                   34                 38.0
# 2016-01-02                   40                   32                 36.0
# 2016-01-03                   45                   35                 40.0
# 2016-01-04                   36                   14                 25.0
# 2016-01-05                   29                   11                 20.0
#
#            precipitation snow fall snow depth
# date
# 2016-01-01          0.00       0.0          0
# 2016-01-02          0.00       0.0          0
# 2016-01-03          0.00       0.0          0
# 2016-01-04          0.00       0.0          0
# 2016-01-05          0.00       0.0          0

# %%
# plt.figure()
weather.plot(linewidth=1)
plt.ylabel('Temperature (F)')
plt.tight_layout()
plt.savefig('powerpoint_pdfs/weather/weather.pdf', format='pdf')

# %% [markdown]
# # Distribution Board Data

# %%
# Read distribution board data -- create datetime columns 

board_data = pd.read_csv('distribution_board_data/archive/2016.csv')
board_data.head()
# Out:
#                   time  3rd floor lighting and plugs  \
# 0  2016-01-01 00:00:00                           2.0
# 1  2016-01-01 00:01:00                           2.0
# 2  2016-01-01 00:02:00                           2.0
# 3  2016-01-01 00:03:00                           2.0
# 4  2016-01-01 00:04:00                           2.0
#
#    4th floor lighting and plugs  \
# 0                           3.4
# 1                           3.4
# 2                           3.4
# 3                           3.4
# 4                           3.4
#
#    4th floor mechanical 2nd,3rd,5th lighting and plugs  \
# 0                                               12.7
# 1                                               12.7
# 2                                               12.7
# 3                                               12.7
# 4                                               12.7
#
#    6th floor lighting and plugs  7th floor lighting and plugs  \
# 0                           8.5                           7.6
# 1                           8.5                           7.6
# 2                           8.5                           7.6
# 3                           8.5                           7.6
# 4                           8.5                           7.6
#
#    7th floor mechanical, 8th and 9th lighting and plugs  \
# 0                                               18.5
# 1                                               18.5
# 2                                               18.5
# 3                                               18.5
# 4                                               18.5
#
#    cellar power and lighting  elevator  retail  roof mechanical  \
# 0                       22.9       2.5    32.0            -27.2
# 1                       22.9       2.5    32.0            -27.2
# 2                       22.9       2.5    32.0            -27.2
# 3                       22.9       2.5    32.0            -27.2
# 4                       22.9       2.5    32.0            -27.2
#
#    sub-cellar power and lighting
# 0                          101.0
# 1                          101.0
# 2                          101.0
# 3                          101.0
# 4                          101.0

# %%
board_data['time'] = pd.to_datetime(board_data['time'])
board_data['date'] = board_data['time'].apply(lambda x: x.date())
board_data['Time'] = board_data['time'].apply(lambda x: x.time())
board_data['year'] = board_data['time'].apply(lambda x: x.year)     
board_data['month'] = board_data['time'].apply(lambda x: x.month)
board_data['day'] = board_data['time'].apply(lambda x: x.day)
board_data['hour'] = board_data['time'].apply(lambda x: x.hour)
board_data['Weekday'] = board_data['time'].apply(lambda x: calendar.day_name[x.weekday()])

# %%
board_data['date'] = pd.to_datetime(board_data['date'], format='%Y-%m-%d')
smoothed_board_data = board_data.groupby('date').mean()
smoothed_board_data.head()
# Out:
#             3rd floor lighting and plugs  4th floor lighting and plugs  \
# date
# 2016-01-01                      2.026667                      3.517188
# 2016-01-02                      2.029028                      3.606100
# 2016-01-03                      2.021632                      3.617182
# 2016-01-04                      2.058449                      3.666065
# 2016-01-05                      2.042870                      3.618275
#
#             4th floor mechanical 2nd,3rd,5th lighting and plugs  \
# date
# 2016-01-01                                          12.550937
# 2016-01-02                                          11.148981
# 2016-01-03                                          10.081192
# 2016-01-04                                          16.314977
# 2016-01-05                                          15.537280
#
#             6th floor lighting and plugs  7th floor lighting and plugs  \
# date
# 2016-01-01                      8.447153                      7.735208
# 2016-01-02                      8.129583                      8.381424
# 2016-01-03                      8.141753                      8.394468
# 2016-01-04                      8.381042                      8.370625
# 2016-01-05                      8.377361                      8.257812
#
#             7th floor mechanical, 8th and 9th lighting and plugs  \
# date
# 2016-01-01                                          18.235694
# 2016-01-02                                          14.576725
# 2016-01-03                                          12.559635
# 2016-01-04                                          24.383113
# 2016-01-05                                          26.701111
#
#             cellar power and lighting  elevator     retail  roof mechanical  \
# date
# 2016-01-01                  25.976562  2.649375  22.586806       -25.040451
# 2016-01-02                  28.910255  2.652396  12.187326       -25.651933
# 2016-01-03                  26.742373  2.577708  10.975660       -25.611921
# 2016-01-04                  32.712882  4.078519  19.428958       119.557535
# 2016-01-05                  33.549884  3.354201  24.050428       188.296968
#
#             sub-cellar power and lighting    year  month  day  hour
# date
# 2016-01-01                     101.582396  2016.0    1.0  1.0  11.5
# 2016-01-02                     102.479583  2016.0    1.0  2.0  11.5
# 2016-01-03                     102.110405  2016.0    1.0  3.0  11.5
# 2016-01-04                     104.979896  2016.0    1.0  4.0  11.5
# 2016-01-05                     105.240937  2016.0    1.0  5.0  11.5

# %%
boards = {  '3rd floor lighting and plugs',
            '4th floor lighting and plugs',
            '4th floor mechanical 2nd,3rd,5th lighting and plugs',
            '6th floor lighting and plugs',
            '7th floor lighting and plugs',
            '7th floor mechanical, 8th and 9th lighting and plugs',
            'cellar power and lighting',
            'elevator',
            'retail',
#             'roof mechanical',
            'sub-cellar power and lighting'  }

plt.figure()
plt.title("Energy Use and Temperature" )
plt.ylabel("Energy Use")

for board in boards:
    smoothed_board_data.loc[:'2016-9-30', board].plot( legend=board, linewidth=1.25)

weather.loc[:'2016-9-30', 'average temperature'].plot(color='b', linewidth=2.4) 
lgd = plt.legend(bbox_to_anchor=(1.05, 1), loc=2, ncol=1)
# plt.tight_layout()
plt.savefig('powerpoint_pdfs\weather/all_ts.pdf', format='pdf', bbox_extra_artists=(lgd,), bbox_inches='tight')

plt.show()

# %% [markdown]
# # Find correlation coefficient between weather data and energy data

# %%
correlations = {}
for board in boards:
    correlations[board] = weather.loc[:'2016-9-30', 'average temperature'].corr(smoothed_board_data[board].loc[:'2016-9-30'])

# %%
correlations = pd.DataFrame.from_dict(correlations, orient='index')
correlations.columns = ['correlation']
correlations['correlation'] = abs( correlations['correlation'] )
correlations = correlations.sort_values('correlation', ascending=True)

# %%
plt.figure()
correlations.plot( kind='barh', figsize=(10, 5) )
plt.tight_layout()
# plt.savefig('powerpoint_pdfs\weather/corr.pdf', format='pdf')
plt.show()

# %%
plt.show()

# %%
plt.close('all')

# %% [markdown]
# # plot scatter plot

# %%
correlations = {}
for board in boards:
    plt.figure()
#     plt.tight_layout()
    df = pd.concat( [weather.loc[:'2016-9-30', 'average temperature'], smoothed_board_data[board].loc[:'2016-9-30']], axis=1 )
    df.plot( kind='scatter', x='average temperature', y=board)
    plt.savefig('powerpoint_pdfs/weather/scatterplots/{}'.format(board) )
