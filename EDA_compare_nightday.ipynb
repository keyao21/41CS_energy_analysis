# %%
import pandas as pd

board_data = pd.read_csv('distribution_board_data/archive/distribution_bds.csv')
board_data.head()
# Out:
#                   time  3rd floor lighting and plugs  \
# 0  2016-01-01 00:00:00                           2.0
# 1  2016-01-01 00:01:00                           2.0
# 2  2016-01-01 00:02:00                           2.0
# 3  2016-01-01 00:03:00                           2.0
# 4  2016-01-01 00:04:00                           2.0
#
#    4th floor lighting and plugs  \
# 0                           3.4
# 1                           3.4
# 2                           3.4
# 3                           3.4
# 4                           3.4
#
#    4th floor mechanical 2nd,3rd,5th lighting and plugs  \
# 0                                               12.7
# 1                                               12.7
# 2                                               12.7
# 3                                               12.7
# 4                                               12.7
#
#    6th floor lighting and plugs  7th floor lighting and plugs  \
# 0                           8.5                           7.6
# 1                           8.5                           7.6
# 2                           8.5                           7.6
# 3                           8.5                           7.6
# 4                           8.5                           7.6
#
#    7th floor mechanical, 8th and 9th lighting and plugs  \
# 0                                               18.5
# 1                                               18.5
# 2                                               18.5
# 3                                               18.5
# 4                                               18.5
#
#    cellar power and lighting  elevator  retail  roof mechanical  \
# 0                       22.9       2.5    32.0            -27.2
# 1                       22.9       2.5    32.0            -27.2
# 2                       22.9       2.5    32.0            -27.2
# 3                       22.9       2.5    32.0            -27.2
# 4                       22.9       2.5    32.0            -27.2
#
#    sub-cellar power and lighting
# 0                          101.0
# 1                          101.0
# 2                          101.0
# 3                          101.0
# 4                          101.0

# %%
board_data['time'] = pd.to_datetime(board_data['time'])
board_data['year'] = board_data['time'].apply(lambda x: x.year)     
board_data['month'] = board_data['time'].apply(lambda x: x.month)
board_data['day'] = board_data['time'].apply(lambda x: x.day)
board_data['hour'] = board_data['time'].apply(lambda x: x.hour)
board_data['min'] = board_data['time'].apply(lambda x: x.minute)

board_data = board_data.loc[((board_data['hour']==0) | (board_data['hour']==12))  & (board_data['min']==0) ]  
board_data = board_data.groupby(['month', 'day', 'hour', 'min']).mean()
board_data = board_data.reset_index()
board_data = pd.merge(board_data.loc[board_data['hour']==12], 
    board_data.loc[board_data['hour']==0], how='inner', on=['year','month', 'day'])

board_data.index = pd.to_datetime(board_data[['year', 'month', 'day']])

# %%
board_data.head()
# Out:
#             month  day  hour_x  min_x  3rd floor lighting and plugs_x  \
# 2016-01-01      1    1      12      0                             2.0
# 2016-01-02      1    2      12      0                             1.8
# 2016-01-03      1    3      12      0                             1.8
# 2016-01-04      1    4      12      0                             1.9
# 2016-01-05      1    5      12      0                             2.3
#
#             4th floor lighting and plugs_x  \
# 2016-01-01                            3.40
# 2016-01-02                            3.30
# 2016-01-03                            3.20
# 2016-01-04                            7.90
# 2016-01-05                            3.35
#
#             4th floor mechanical 2nd,3rd,5th lighting and plugs_x  \
# 2016-01-01                                              12.70
# 2016-01-02                                              12.80
# 2016-01-03                                              14.30
# 2016-01-04                                              25.25
# 2016-01-05                                              22.30
#
#             6th floor lighting and plugs_x  7th floor lighting and plugs_x  \
# 2016-01-01                            8.50                            7.60
# 2016-01-02                            8.25                            8.85
# 2016-01-03                            8.30                            7.70
# 2016-01-04                            8.90                            8.55
# 2016-01-05                            8.25                            8.80
#
#             7th floor mechanical, 8th and 9th lighting and plugs_x  \
# 2016-01-01                                              18.50
# 2016-01-02                                              17.95
# 2016-01-03                                              16.95
# 2016-01-04                                              36.40
# 2016-01-05                                              37.20
#
#                          ...                 4th floor lighting and plugs_y  \
# 2016-01-01               ...                                            3.4
# 2016-01-02               ...                                            3.7
# 2016-01-03               ...                                            3.5
# 2016-01-04               ...                                            3.3
# 2016-01-05               ...                                            3.2
#
#             4th floor mechanical 2nd,3rd,5th lighting and plugs_y  \
# 2016-01-01                                              12.70
# 2016-01-02                                               8.70
# 2016-01-03                                               8.20
# 2016-01-04                                               8.25
# 2016-01-05                                              12.40
#
#             6th floor lighting and plugs_y  7th floor lighting and plugs_y  \
# 2016-01-01                            8.50                            7.60
# 2016-01-02                            8.00                            7.40
# 2016-01-03                            8.15                            8.50
# 2016-01-04                            8.10                            8.25
# 2016-01-05                            8.05                            8.10
#
#             7th floor mechanical, 8th and 9th lighting and plugs_y  \
# 2016-01-01                                              18.50
# 2016-01-02                                              10.70
# 2016-01-03                                              10.10
# 2016-01-04                                              11.10
# 2016-01-05                                              22.35
#
#             cellar power and lighting_y  elevator_y  retail_y  \
# 2016-01-01                        22.90         2.5     32.00
# 2016-01-02                        19.90         2.5     13.60
# 2016-01-03                        28.20         2.5     13.30
# 2016-01-04                        26.35         2.5     13.30
# 2016-01-05                        38.50         1.8     14.15
#
#             roof mechanical_y  sub-cellar power and lighting_y
# 2016-01-01             -27.20                           101.00
# 2016-01-02             -25.80                           102.85
# 2016-01-03             -25.65                           102.90
# 2016-01-04             -24.55                           104.30
# 2016-01-05             184.30                           102.35
#
# [5 rows x 29 columns]

# %% [markdown]
# # Plot the 12 am vs. 12 pm energy usage for each day, for each distribution board

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')


boards = {'3rd floor lighting and plugs',
       '4th floor lighting and plugs',
       '4th floor mechanical 2nd,3rd,5th lighting and plugs',
       '6th floor lighting and plugs', '7th floor lighting and plugs',
       '7th floor mechanical, 8th and 9th lighting and plugs',
       'cellar power and lighting', 'elevator', 'retail',
       'roof mechanical', 'sub-cellar power and lighting'
         }

all_diffs = []
for board in boards:
    night, day = board_data[ '{}_y'.format(board) ], board_data[ '{}_x'.format(board) ] 
    plt.figure()
    plt.title(board)
#     plt.plot(day)
#     plt.plot(night)
    day.plot(label='day')
    night.plot(label='night')
    plt.legend()
#     d.legend()
    plt.show()
    all_diffs.append( [board, (day-night).mean()] )

# %%
plt.figure()
df = pd.DataFrame(all_diffs).sort_values(1, ascending=True)
df.columns = ['Distribution_Boards', 'Avg_Diff_Day_Night']
df = df.set_index('Distribution_Boards')
df.plot(kind='barh')
plt.title('Average Energy Usage between Night and Day')
plt.show()

# %% [markdown]
# From the graph above, we see that in general, energy usage is pretty steady for the lighting and plugs across night and day. This has a lot of potential for energy savings!!!
